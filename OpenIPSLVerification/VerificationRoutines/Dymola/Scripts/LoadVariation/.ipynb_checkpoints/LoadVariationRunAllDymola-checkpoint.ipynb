# %%
import platform
from dymola.dymola_interface import DymolaInterface
from dymola.dymola_exception import DymolaException
from modelicares import SimRes
import pandas as pd
import numpy as np
import os
import shutil

# %%
#This is intended to be used in the manuelnvro Dell using Dymola 2020

# %%
#Run Exciters
print('---------------------------------------------------------- Load Variation Exciters Testing ----------------------------------------------------------')
try:
    os.chdir(f"/home/manuelnvro/dev/Gitted/NYPAModelTransformation/OpenIPSLVerification/VerificationRoutines/Dymola/Scripts/LoadVariation/")
    exec(open("LoadVariationExcitersDymola.py").read())
    print('Load Variation Exciters Testing OK...')
except:
    print('Error in Load Variation Exciters Testing...')
# Out:
# ---------------------------------------------------------- Load Variation Exciters Testing ----------------------------------------------------------
# Load Variation Dymola Exciters Simulation Start...
#
# Load Variation AC7B Simulation Start...
# Load Variation AC7B Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.ES.AC7B">OpenIPSL.Examples.Controls.PSSE.ES.AC7B</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.ES.AC7B
# Error: ERRORS have been issued.
#
# Load Variation AC8B Simulation Start...
# Load Variation AC8B Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.ES.AC8B">OpenIPSL.Examples.Controls.PSSE.ES.AC8B</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.ES.AC8B
# Error: ERRORS have been issued.
#
# Load Variation ESAC1A Simulation Start...
# Load Variation ESAC1A Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# ESAC1A Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# ESAC1A Variables OK...
# ESAC1A Write OK...
# Load Variation ESAC2A Simulation Start...
# Load Variation ESAC2A Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# ESAC2A Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# ESAC2A Variables OK...
# ESAC2A Write OK...
# Load Variation ESAC6A Simulation Start...
# Load Variation ESAC6A Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.ES.ESAC6A">OpenIPSL.Examples.Controls.PSSE.ES.ESAC6A</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.ES.ESAC6A
# Error: ERRORS have been issued.
#
# Load Variation ESDC1A Simulation Start...
# Load Variation ESDC1A Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# ESDC1A Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# ESDC1A Variables OK...
# ESDC1A Write OK...
# Load Variation ESST1A Simulation Start...
# Load Variation ESST1A Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# ESST1A Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# ESST1A Variables OK...
# ESST1A Write OK...
# Load Variation ESST3A Simulation Start...
# Load Variation ESST3A Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.ES.ESST3A">OpenIPSL.Examples.Controls.PSSE.ES.ESST3A</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.ES.ESST3A
# Error: ERRORS have been issued.
#
# Load Variation ESST4B Simulation Start...
# Load Variation ESST4B Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# ESST4B Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# ESST4B Variables OK...
# ESST4B Write OK...
# Load Variation EXAC1 Simulation Start...
# Load Variation EXAC1 Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# EXAC1 Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# EXAC1 Variables OK...
# EXAC1 Write OK...
# Load Variation EXAC2 Simulation Start...
# Load Variation EXAC2 Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# EXAC2 Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# EXAC2 Variables OK...
# EXAC2 Write OK...
# Load Variation EXAC3 Simulation Start...
# Load Variation EXAC3 Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.ES.EXAC3">OpenIPSL.Examples.Controls.PSSE.ES.EXAC3</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.ES.EXAC3
# Error: ERRORS have been issued.
#
# Load Variation EXDC2 Simulation Start...
# Load Variation EXDC2 Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.ES.EXDC2">OpenIPSL.Examples.Controls.PSSE.ES.EXDC2</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.ES.EXDC2
# Error: ERRORS have been issued.
#
# Load Variation EXPIC1 Simulation Start...
# Load Variation EXPIC1 Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.ES.EXPIC1">OpenIPSL.Examples.Controls.PSSE.ES.EXPIC1</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.ES.EXPIC1
# Error: ERRORS have been issued.
#
# Load Variation EXST1 Simulation Start...
# Load Variation EXST1 Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# EXST1 Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# EXST1 Variables OK...
# EXST1 Write OK...
# Load Variation EXST3 Simulation Start...
# Load Variation EXST3 Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.ES.EXST3">OpenIPSL.Examples.Controls.PSSE.ES.EXST3</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.ES.EXST3
# Error: ERRORS have been issued.
#
# Load Variation IEEET1 Simulation Start...
# Load Variation IEEET1 Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# IEEET1 Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# IEEET1 Variables OK...
# IEEET1 Write OK...
# Load Variation IEEET2 Simulation Start...
# Load Variation IEEET2 Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# IEEET2 Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# IEEET2 Variables OK...
# IEEET2 Write OK...
# Load Variation IEEET3 Simulation Start...
# Load Variation IEEET3 Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.ES.IEEET3">OpenIPSL.Examples.Controls.PSSE.ES.IEEET3</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.ES.IEEET3
# Error: ERRORS have been issued.
#
# Load Variation IEEET5 Simulation Start...
# Load Variation IEEET5 Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.ES.IEEET5">OpenIPSL.Examples.Controls.PSSE.ES.IEEET5</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.ES.IEEET5
# Error: ERRORS have been issued.
#
# Load Variation REXSYS Simulation Start...
# Load Variation REXSYS Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.ES.REXSYS">OpenIPSL.Examples.Controls.PSSE.ES.REXSYS</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.ES.REXSYS
# Error: ERRORS have been issued.
#
# Load Variation SCRX Simulation Start...
# Load Variation SCRX Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# SCRX Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# SCRX Variables OK...
# SCRX Write OK...
# Load Variation SEXS Simulation Start...
# Load Variation SEXS Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# SEXS Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# SEXS Variables OK...
# SEXS Write OK...
# Load Variation ST6B Simulation Start...
# Load Variation ST6B Simulation Start...
# Editing SMIB Partial Model for Load Variation Testing...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.ES.ST6B">OpenIPSL.Examples.Controls.PSSE.ES.ST6B</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.ES.ST6B
# Error: ERRORS have been issued.
#
# Fault Exciter Examples Simulation OK...
# Load Variation Exciters Testing OK...

# %%
#Run Machines
print('---------------------------------------------------------- Load Variation Machines Testing ----------------------------------------------------------')
try:
    os.chdir(f"/home/manuelnvro/dev/Gitted/NYPAModelTransformation/OpenIPSLVerification/VerificationRoutines/Dymola/Scripts/LoadVariation/")
    exec(open("LoadVariationMachinesDymola.py").read())
    print('Load Variation Machines Testing OK...')
except:
    print('Load Variation Error in Machines Testing...')
# Out:
# ---------------------------------------------------------- Machines Testing ----------------------------------------------------------
# Error in Exciters Testing...

# %%
#Run Turbine Governors
print('---------------------------------------------------------- Load Variation Turbine Governors Testing ----------------------------------------------------------')
try:
    os.chdir(f"/home/manuelnvro/dev/Gitted/NYPAModelTransformation/OpenIPSLVerification/VerificationRoutines/Dymola/Scripts/LoadVariation/")
    exec(open("LoadVariationTurbineGovernorsDymola.py").read())
    print('Load Variation Turbine Governors Testing OK...')
except:
    print('Error in Load Variation Turbine Governors Testing...')
# Out:
# ---------------------------------------------------------- Turbine Governors Testing ----------------------------------------------------------
# Dymola Turbine Governors Simulation Start...
#
# BBGOV1 Simulation Start...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.TG.BBGOV1">OpenIPSL.Examples.Controls.PSSE.TG.BBGOV1</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.TG.BBGOV1
# Error: ERRORS have been issued.
#
# Delete OK...
#
# GAST Simulation Start...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.TG.GAST">OpenIPSL.Examples.Controls.PSSE.TG.GAST</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.TG.GAST
# Error: ERRORS have been issued.
#
# Delete OK...
#
# GAST2A Simulation Start...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.TG.GAST2A">OpenIPSL.Examples.Controls.PSSE.TG.GAST2A</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.TG.GAST2A
# Error: ERRORS have been issued.
#
# Delete OK...
#
# GGOV1 Simulation Start...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.TG.GGOV1">OpenIPSL.Examples.Controls.PSSE.TG.GGOV1</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.TG.GGOV1
# Error: ERRORS have been issued.
#
# Delete OK...
#
# HYGOV Simulation Start...
# HYGOV Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# Not a GENROE model...
# Verifying if it is a GENSAL model...
# HYGOV Variables OK...
# HYGOV Write OK...
# Delete OK...
#
# IEEG1 Simulation Start...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.TG.IEEG1">OpenIPSL.Examples.Controls.PSSE.TG.IEEG1</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.TG.IEEG1
# Error: ERRORS have been issued.
#
# Delete OK...
#
# IEESGO Simulation Start...
# IEESGO Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# Not a GENROE model...
# Verifying if it is a GENSAL model...
# IEESGO Variables OK...
# IEESGO Write OK...
# Delete OK...
#
# TGOV1 Simulation Start...
# TGOV1 Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# TGOV1 Variables OK...
# TGOV1 Write OK...
# Not a GENROE model...
# Verifying if it is a GENSAL model...
# Not a GENSAL model...
# Delete OK...
#
# WEHGOV Simulation Start...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.TG.WEHGOV">OpenIPSL.Examples.Controls.PSSE.TG.WEHGOV</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.TG.WEHGOV
# Error: ERRORS have been issued.
#
# Delete OK...
#
# WESGOV Simulation Start...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.TG.WESGOV">OpenIPSL.Examples.Controls.PSSE.TG.WESGOV</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.TG.WESGOV
# Error: ERRORS have been issued.
#
# Delete OK...
#
# WSHYDD Simulation Start...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.TG.WSHYDD">OpenIPSL.Examples.Controls.PSSE.TG.WSHYDD</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.TG.WSHYDD
# Error: ERRORS have been issued.
#
# Delete OK...
#
# WSHYGP Simulation Start...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.TG.WSHYGP">OpenIPSL.Examples.Controls.PSSE.TG.WSHYGP</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.TG.WSHYGP
# Error: ERRORS have been issued.
#
# Delete OK...
#
# Turbine Governor Examples Simulation OK...
# Turbine Governors Testing OK...

# %%
#Run Power System Stabilizer
print('---------------------------------------------------------- Load Variation Power System Stabilizers Testing ----------------------------------------------------------')
try:
    os.chdir(f"/home/manuelnvro/dev/Gitted/NYPAModelTransformation/OpenIPSLVerification/VerificationRoutines/Dymola/Scripts/LoadVariation/")
    exec(open("LoadVariationPowerSystemStabilizersDymola.py").read())
    print('Load Variation Power System Stabilizer Testing OK...')
except:
    print('Error in Load Variation Power System Stabilizer Testing...')
# Out:
# ---------------------------------------------------------- Power System Stabilizers Testing ----------------------------------------------------------
# Dymola Power System Stabilizers Simulation Start...
#
# PSS2A Simulation Start...
# PSS2A Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# PSS2A Variables OK...
# PSS2A Write OK...
# Delete OK...
#
# PSS2B Simulation Start...
# PSS2B Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# PSS2B Variables OK...
# PSS2B Write OK...
# Delete OK...
#
# Power System Stabilizers Simulation OK...
# Power System Stabilizer Testing OK...

# %%
print('---------------------------------------------------------- End of All Fault Simulations ----------------------------------------------------------')
