# %%
from OMPython import OMCSessionZMQ
omc = OMCSessionZMQ()
from modelicares import SimRes
import pandas as pd
import numpy as np
import os
import shutil
import git
# Out:
# 2020-04-07 13:59:26,380 - OMPython - INFO - OMC Server is up and running at file:////tmp/openmodelica.manuelnvro.port.ad16ddb5e4b24985b8ceeab5de3c6051 pid=21883

# %%
#This is intended to be used in the manuelnvro Dell using Dymola 2020
ReferenceStep = "/home/manuelnvro/dev/Gitted/NYPAModelTransformation/OpenIPSLVerification/VerificationRoutines/OpenModelica/Scripts/ReferenceStep/"

# %%
#Run Exciters
print('---------------------------------------------------------- Reference Step Open Modelica Exciters Testing ----------------------------------------------------------')
try:
    os.chdir(f""+ReferenceStep+"")
    exec(open("ReferenceStepExcitersOpenModelica.py").read())
    print('Reference Step Open Modelica Exciters Testing OK...')
except:
    print('Error in Reference Step Open Modelica Exciters Testing...')
# Out:
# ---------------------------------------------------------- Fault Open Modelica Exciters Testing ----------------------------------------------------------
# 2020-04-07 13:59:29,036 - OMPython - INFO - OMC Server is up and running at file:////tmp/openmodelica.manuelnvro.port.e2c5ba43954c4549ab11ffb647fe8485 pid=21896
# OpenModelica 1.16.0~dev-263-g761b5de
# Open Modelica Exciters Simulation Start...
# Pulling latest OpenIPSL library version...
#
# Fault AC7B Simulation Start...
# AC7B simulation error or model not found...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# AC7B variable error...
#
# Delete OK...
#
# Fault AC8B Simulation Start...
# AC8B simulation error or model not found...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# AC8B variable error...
#
# Delete OK...
#
# Fault ESAC1A Simulation Start...
# ESAC1A Simulation Finished...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# ESAC1A Variables OK...
# ESAC1A Write OK...
# Delete OK...
#
# Fault ESAC2A Simulation Start...
# ESAC2A Simulation Finished...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# ESAC2A Variables OK...
# ESAC2A Write OK...
# Delete OK...
#
# Fault ESAC6A Simulation Start...
# ESAC6A simulation error or model not found...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# ESAC6A variable error...
#
# Delete OK...
#
# Fault ESDC1A Simulation Start...
# ESDC1A Simulation Finished...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# ESDC1A Variables OK...
# ESDC1A Write OK...
# Delete OK...
#
# Fault ESST1A Simulation Start...
# ESST1A Simulation Finished...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# ESST1A Variables OK...
# ESST1A Write OK...
# Delete OK...
#
# Fault ESST3A Simulation Start...
# ESST3A simulation error or model not found...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# ESST3A variable error...
#
# Delete OK...
#
# Fault ESST4B Simulation Start...
# ESST4B Simulation Finished...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# ESST4B Variables OK...
# ESST4B Write OK...
# Delete OK...
#
# Fault EXAC1 Simulation Start...
# EXAC1 Simulation Finished...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# EXAC1 Variables OK...
# EXAC1 Write OK...
# Delete OK...
#
# Fault EXAC2 Simulation Start...
# EXAC2 Simulation Finished...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# EXAC2 Variables OK...
# EXAC2 Write OK...
# Delete OK...
#
# Fault EXAC3 Simulation Start...
# EXAC3 simulation error or model not found...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# EXAC3 variable error...
#
# Delete OK...
#
# Fault EXDC2 Simulation Start...
# EXDC2 simulation error or model not found...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# EXDC2 variable error...
#
# Delete OK...
#
# Fault EXPIC1 Simulation Start...
# EXPIC1 simulation error or model not found...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# EXPIC1 variable error...
#
# Delete OK...
#
# Fault EXST1 Simulation Start...
# EXST1 Simulation Finished...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# EXST1 Variables OK...
# EXST1 Write OK...
# Delete OK...
#
# Fault EXST3 Simulation Start...
# EXST3 simulation error or model not found...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# EXST3 variable error...
#
# Delete OK...
#
# Fault IEEET1 Simulation Start...
# IEEET1 Simulation Finished...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# IEEET1 Variables OK...
# IEEET1 Write OK...
# Delete OK...
#
# Fault IEEET2 Simulation Start...
# IEEET2 simulation error or model not found...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# IEEET2 variable error...
#
# Delete OK...
#
# Fault IEEET3 Simulation Start...
# IEEET3 simulation error or model not found...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# IEEET3 variable error...
#
# Delete OK...
#
# Fault IEEET5 Simulation Start...
# IEEET5 simulation error or model not found...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# IEEET5 variable error...
#
# Delete OK...
#
# Fault REXSYS Simulation Start...
# REXSYS simulation error or model not found...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# REXSYS variable error...
#
# Delete OK...
#
# Fault SCRX Simulation Start...
# SCRX Simulation Finished...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# SCRX Variables OK...
# SCRX Write OK...
# Delete OK...
#
# Fault SEXS Simulation Start...
# SEXS Simulation Finished...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# SEXS Variables OK...
# SEXS Write OK...
# Delete OK...
#
# Fault ST6B Simulation Start...
# ST6B simulation error or model not found...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# ST6B variable error...
#
# Delete OK...
#
# Fault Exciter Examples Open Modelica Simulation OK...
# Closing Open Modelica...
# OpenModelica Close OK...
# Fault Open Modelica Exciters Testing OK...

# %%
#Run Machines
print('---------------------------------------------------------- Reference Step Open Modelica Machines Testing ----------------------------------------------------------')
try:
    os.chdir(f""+ReferenceStep+"")
    exec(open("ReferenceStepMachinesOpenModelica.py").read())
    print('Reference Step Open Modelica Machines Testing OK...')
except:
    print('Error in Reference Step Open Modelica in Machines Testing...')
# Out:
# ---------------------------------------------------------- Fault Open Modelica Machines Testing ----------------------------------------------------------
# 2020-04-07 14:01:00,252 - OMPython - INFO - OMC Server is up and running at file:////tmp/openmodelica.manuelnvro.port.f7716a70bf7245d9b113373e3140d37f pid=22895
# OpenModelica 1.16.0~dev-263-g761b5de
# Open Modelica Machines Simulation Start...
# Pulling latest OpenIPSL library version...
#
# Error in Fault Open Modelica in Machines Testing...

# %%
#Run Turbine Governors
print('---------------------------------------------------------- Reference Step Open Modelica Turbine Governors Testing ----------------------------------------------------------')
try:
    os.chdir(f""+ReferenceStep+"")
    exec(open("ReferenceStepTurbineGovernorsOpenModelica.py").read())
    print('Reference Step Open Modelica Turbine Governors Testing OK...')
except:
    print('Error in Reference Step Open Modelica Turbine Governors Testing...')
# Out:
# ---------------------------------------------------------- Fault Dymola Turbine Governors Testing ----------------------------------------------------------
# Pulling latest OpenIPSL library version...
#
# Fault Dymola Turbine Governors Simulation Start...
#
# Fault BBGOV1 Simulation Start...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.TG.BBGOV1">OpenIPSL.Examples.Controls.PSSE.TG.BBGOV1</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.TG.BBGOV1
# Error: ERRORS have been issued.
#
# Delete OK...
#
# Fault GAST Simulation Start...
# GAST Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# GAST Variables OK...
# GAST Write OK...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# Not a GENROE model...
# Verifying if it is a GENSAL model...
# Not a GENSAL model...
# Delete OK...
#
# Fault GAST2A Simulation Start...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.TG.GAST2A">OpenIPSL.Examples.Controls.PSSE.TG.GAST2A</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.TG.GAST2A
# Error: ERRORS have been issued.
#
# Delete OK...
#
# Fault GGOV1 Simulation Start...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.TG.GGOV1">OpenIPSL.Examples.Controls.PSSE.TG.GGOV1</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.TG.GGOV1
# Error: ERRORS have been issued.
#
# Delete OK...
#
# Fault HYGOV Simulation Start...
# HYGOV Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# Not a GENROE model...
# Verifying if it is a GENSAL model...
# HYGOV Variables OK...
# HYGOV Write OK...
# Delete OK...
#
# Fault IEEEG1 Simulation Start...
# IEEEG1 Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# Not a GENROE model...
# Verifying if it is a GENSAL model...
# Not a GENSAL model...
# Delete OK...
#
# Fault IEESGO Simulation Start...
# IEESGO Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# Not a GENROE model...
# Verifying if it is a GENSAL model...
# IEESGO Variables OK...
# IEESGO Write OK...
# Delete OK...
#
# Fault TGOV1 Simulation Start...
# TGOV1 Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# Not a GENROU model...
# Verifying if it is a GENROE model...
# TGOV1 Variables OK...
# TGOV1 Write OK...
# Not a GENROE model...
# Verifying if it is a GENSAL model...
# Not a GENSAL model...
# Delete OK...
#
# Fault WEHGOV Simulation Start...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.TG.WEHGOV">OpenIPSL.Examples.Controls.PSSE.TG.WEHGOV</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.TG.WEHGOV
# Error: ERRORS have been issued.
#
# Delete OK...
#
# Fault WESGOV Simulation Start...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.TG.WESGOV">OpenIPSL.Examples.Controls.PSSE.TG.WESGOV</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.TG.WESGOV
# Error: ERRORS have been issued.
#
# Delete OK...
#
# Fault WSHYDD Simulation Start...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.TG.WSHYDD">OpenIPSL.Examples.Controls.PSSE.TG.WSHYDD</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.TG.WSHYDD
# Error: ERRORS have been issued.
#
# Delete OK...
#
# Fault WSHYGP Simulation Start...
# Simulation failed or model was not found. Below is the translation log:
#
# Translation of <a href="Modelica://OpenIPSL.Examples.Controls.PSSE.TG.WSHYGP">OpenIPSL.Examples.Controls.PSSE.TG.WSHYGP</a>:
# Did not find model OpenIPSL.Examples.Controls.PSSE.TG.WSHYGP
# Error: ERRORS have been issued.
#
# Delete OK...
#
# Fault Turbine Governor Examples Simulation OK...
# Closing Dymola...
# Dymola Close OK...
# Fault Dymola Turbine Governors Testing OK...

# %%
#Run Power System Stabilizer
print('---------------------------------------------------------- Reference Step Open Modelica Power System Stabilizers Testing ----------------------------------------------------------')
try:
    os.chdir(f""+ReferenceStep+"")
    exec(open("ReferenceStepPowerSystemStabilizersOpenModelica.py").read())
    print('Reference Step Open Modelica Power System Stabilizer Testing OK...')
except:
    print('Error in Reference Step Open Modelica Power System Stabilizer Testing...')
# Out:
# ---------------------------------------------------------- Power System Stabilizers Testing ----------------------------------------------------------
# Dymola Power System Stabilizers Simulation Start...
#
# PSS2A Simulation Start...
# PSS2A Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# PSS2A Variables OK...
# PSS2A Write OK...
# Delete OK...
#
# PSS2B Simulation Start...
# PSS2B Simulation OK...
# .csv Writing Start...
# Verifying if it is a GENROU model...
# PSS2B Variables OK...
# PSS2B Write OK...
# Delete OK...
#
# Power System Stabilizers Simulation OK...
# Power System Stabilizer Testing OK...

# %%
#Run Wind Turbines
print('---------------------------------------------------------- Reference Step Open Modelica Wind Turbines Testing ----------------------------------------------------------')
try:
    os.chdir(f""+ReferenceStep+"")
    exec(open("ReferenceStepWindTurbinesOpenModelica.py").read())
    print('Reference Step Open Modelica Wind Turbines Testing OK...')
except:
    print('Error in Reference Step Open Modelica Wind Turbines Testing...')
# Out:
# ---------------------------------------------------------- Fault Dymola Wind Turbines Testing ----------------------------------------------------------
# Error in Fault Dymola Wind Turbines Testing...

# %%
print('---------------------------------------------------------- End of Reference Step Open Modelica Simulations ----------------------------------------------------------')
